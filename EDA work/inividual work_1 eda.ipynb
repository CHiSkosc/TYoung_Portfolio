# %%
import pandas as pd
import duckdb as db

# %%
#loading data
o_material = pd.read_csv("C:\\Users\\young\\OneDrive\\Documents\\Masters\\Fall 2025\\IS6813 Capstone 3\\data\\material.csv")

#create copy
material = o_material.copy()

# %% [markdown]
# reviewing the data

# %%
# %%sql
# pd.material.info()
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_sql1 = __import__("duckdb").execute(__import__('base64').b64decode('cGQubWF0ZXJpYWwuaW5mbygp').decode('utf-8')).fetchdf()
#       2 df_sql1
#
# ParserException: Parser Error: syntax error at or near "pd"
#
# LINE 1: pd.material.info()
#         ^
